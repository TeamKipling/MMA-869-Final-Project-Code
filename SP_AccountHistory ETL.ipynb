# %%
import pandas as pd
import os as os
import pandasql as psql
from pandasql import sqldf
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import pymysql
import pandas as pd


#Set max display rows for EDA
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

path = r"C:\Users\Tom-T\Google Drive\Queen's MMA\Machine Learning & AI - MMA 869\Final Project - Scene Dataset\Transaction Categories.csv"
data = pd.read_csv(path, encoding = 'latin-1')
data.head(100)
# Out:
#       Ex_Transactiondescription  Count of Instances Percent  \
# 0                    tim horton               92467      8%
# 1                     mcdonalds               43802      4%
# 2            step_goal_complete               42205      4%
# 3                       walmart               34590      3%
# 4                 adult tickets               20837      2%
# 5                 shoppers drug               19957      2%
# 6                  intervention               17917      1%
# 7                          uber               15747      1%
# 8                        subway               15519      1%
# 9                     dollarama               14894      1%
# 10                 petro-canada               14605      1%
# 11                  concessions               13330      1%
# 12           cara points earned               13176      1%
# 13                         esso               12873      1%
# 14                       sobeys               12611      1%
# ...

# %%
#Convert HistoryDt integer field into datetime
data['HistoryDt'] = pd.to_datetime(data['HistoryDt'], format="%Y-%m-%d %H:%M:%S")
data['HistoryDt'] = data['HistoryDt'].dt.date

# %%
data.head()
# Out:
#                Unique_member_identifier  AccountHistoryID   HistoryDt  \
# 0  565C35D2-3DB4-4FFA-BF92-66AB07B38EB9         107762195  2017-08-01
# 1  565C35D2-3DB4-4FFA-BF92-66AB07B38EB9         107762196  2017-08-01
# 2  BDB5A4B4-9346-465A-B774-0DC0387C978D         107779368  2017-08-02
# 3  BDB5A4B4-9346-465A-B774-0DC0387C978D         107779491  2017-08-02
# 4  BDB5A4B4-9346-465A-B774-0DC0387C978D         107779492  2017-08-02
#
#    SourceID  AccountHistoryTypeID
# 0      19.0                     1
# 1      23.0                   272
# 2       4.0                     1
# 3      26.0                    10
# 4      26.0                    10

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

#export dataframe into MySQL table
tableName   = "SP_Transaction_Category"          

sqlEngine       = create_engine('mysql+pymysql://admin:m0mDba4r6y@mma860-teamkipling.ci9pdpp0ny8u.us-east-2.rds.amazonaws.com:3308/MMA_869', pool_recycle = -1)
dbConnection    = sqlEngine.connect()

try:
    frame           = data.to_sql(tableName, dbConnection, if_exists='replace', index=False);
except ValueError as vx:
    print(vx)
except Exception as ex:   
    print(ex)
else:
    print("Table %s created successfully."%tableName);   
finally:
    dbConnection.close()
# Out:
# Table SP_Transaction_Category created successfully.
