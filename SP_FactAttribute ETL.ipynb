# %%
import pandas as pd
import numpy as np
import os as os
import pandasql as psql
from pandasql import sqldf
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import pymysql

path = r"/Users/rakeshdhara/Documents/Master of Management Analytics/23 869 Machine Learning and AI/Group Project/sample01/SceneAnalytics.dbo.SP_FactAttribute.csv"
data = pd.read_csv(path)
# data['Security Officer Name'] = data['Security Officer Name'].str.split('-').str[0]
# data['Security Officer NRIC/FIN Number'] = data['Security Officer NRIC/FIN Number'].str.replace(' ','')
data.head()
#data.to_csv(r"/Users/rakeshdhara/Documents/Master of Management Analytics/23 869 Machine Learning and AI/Group Project/sample01/SceneAnalytics.dbo.SP_FactAttribute.csv", index = False)
# Out:
#                Unique_member_identifier  isActive  \
# 0  108701DA-D45E-4A42-B39D-38BE6E774628      True
# 1  E7E8F6EF-D376-46E9-B911-D574E8371C7C      True
# 2  AE00C271-8F64-48E2-93FE-3BF6ABD6A004      True
# 3  8884A99B-36C3-47A3-8407-F102173458DF      True
# 4  9C94EF89-B7B9-4231-B36F-B522B5DBE218      True
#
#    OnlineTicketPurchaser_tendancy  OnlineTicketPurchaser_value  \
# 0                           False                            7
# 1                           False                            0
# 2                            True                           67
# 3                            True                          100
# 4                           False                            0
#
#    TuesdayAttendee_tendancy  TuesdayAttendee_value  \
# 0                     False                     47
# 1                     False                     33
# 2                     False                     30
# 3                     False                      0
# ...

# %%
#Check for null values
nullcheck = data.isnull().sum()
nullcheck[nullcheck > 0]
# Out:
# Series([], dtype: int64)

# %%
#Check data type
print(data.dtypes)
# Out:
# Unique_member_identifier          object
# isActive                           int64
# OnlineTicketPurchaser_tendancy     int64
# OnlineTicketPurchaser_value        int64
# TuesdayAttendee_tendancy           int64
# TuesdayAttendee_value              int64
# ConcessionPurchaser_tendancy       int64
# ConcessionPurchaser_value          int64
# OpensEmail_tendancy                int64
# OpensEmail_value                  object
# AttendsWithChild_tendancy          int64
# AttendsWithChild_value             int64
# ClicksEmail_tendancy               int64
# ClicksEmail_value                 object
# WeekendMatineeViewer_tendancy      int64
# WeekendMatineeViewer_value         int64
# WeekdayMatineeViewer_tendancy      int64
# WeekdayMatineeViewer_value         int64
# RedemptionYearToDate               int64
# RedemptionProgramToDate            int64
# dtype: object

# %%
#Transformations

#convert multiple features from boolean to integer format
data['isActive'] = data['isActive'].astype(int)
data['OnlineTicketPurchaser_tendancy'] = data['OnlineTicketPurchaser_tendancy'].astype(int)
data['TuesdayAttendee_tendancy'] = data['TuesdayAttendee_tendancy'].astype(int)
data['ConcessionPurchaser_tendancy'] = data['ConcessionPurchaser_tendancy'].astype(int)
data['OpensEmail_tendancy'] = data['OpensEmail_tendancy'].astype(int)
data['AttendsWithChild_tendancy'] = data['AttendsWithChild_tendancy'].astype(int)
data['ClicksEmail_tendancy'] = data['ClicksEmail_tendancy'].astype(int)
data['WeekendMatineeViewer_tendancy'] = data['WeekendMatineeViewer_tendancy'].astype(int)
data['WeekdayMatineeViewer_tendancy'] = data['WeekdayMatineeViewer_tendancy'].astype(int)
data['RedemptionYearToDate'] = data['RedemptionYearToDate'].astype(int)
data['RedemptionProgramToDate'] = data['RedemptionProgramToDate'].astype(int)

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

#export dataframe into MySQL table
tableName   = "SP_FactAttribute"          

sqlEngine       = create_engine('mysql+pymysql://admin:m0mDba4r6y@mma860-teamkipling.ci9pdpp0ny8u.us-east-2.rds.amazonaws.com:3308/MMA_869', pool_recycle = -1)
dbConnection    = sqlEngine.connect()

try:
    frame           = data.to_sql(tableName, dbConnection, if_exists='replace', index=False);
except ValueError as vx:
    print(vx)
except Exception as ex:   
    print(ex)
else:
    print("Table %s created successfully."%tableName);   
finally:
    dbConnection.close()
# Out:
# Table SP_FactAttribute created successfully.
